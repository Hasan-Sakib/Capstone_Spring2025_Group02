# %%
# =========================
# Imports
# =========================
import os, time, random
import numpy as np
from glob import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.models as models
import torchvision.transforms as T

from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler

from PIL import Image
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# =========================
# Paths & Hyperparams
# =========================
# Set this to your Malimg root where subfolders are class names:
root_dir = "/content/drive/MyDrive/Colab Notebooks/malimg_paper_dataset_imgs"

batch_size = 128
pretrain_epochs = 100
finetune_epochs = 100     # early stopping can cut this short
learning_rate = 1e-3     # for SimCLR
finetune_lr  = 1e-4      # for classifier + encoder
temperature  = 0.5
projection_dim = 128
test_ratio = 0.4
patience = 5             # early stopping on train loss (no val per your request)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================
# Dataset helpers
# =========================
def list_images_and_labels(root_dir):
    class_names = sorted([d for d in os.listdir(root_dir)
                          if os.path.isdir(os.path.join(root_dir, d))])
    class_to_idx = {c:i for i,c in enumerate(class_names)}
    img_paths, labels = [], []
    for cls in class_names:
        cls_path = os.path.join(root_dir, cls)
        for f in os.listdir(cls_path):
            p = os.path.join(cls_path, f)
            if os.path.isfile(p):
                img_paths.append(p)
                labels.append(class_to_idx[cls])
    return img_paths, labels, class_names

class MalimgDatasetFromList(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert("RGB")
        label = self.labels[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

class ContrastiveDataset(Dataset):
    """ Wrap a base dataset & return two augmented views for SimCLR. """
    def __init__(self, base_dataset, augment):
        self.base = base_dataset
        self.augment = augment

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, _ = self.base[idx]     # base returns (PIL-transformed tensor, label)
        # If base returns tensors already, ensure augment expects PIL -> ToTensor inside
        # Here, we want PIL input; so build base without transform, and put transforms here.
        # To make that work, ensure base has transform=None (we will below).
        # We'll handle it by reloading image path via base.image_paths if needed.
        # Simpler: create a PIL loader dataset for contrastive step:
        # We'll reconstruct PIL image by path to guarantee augment works.

        # Re-open PIL to ensure augment gets PIL (in case base had ToTensor)
        # (This requires base to have .image_paths; we can check and fallback.)
        if hasattr(self.base, "image_paths"):
            pil = Image.open(self.base.image_paths[idx]).convert("RGB")
        else:
            # Fallback: assume img is PIL already
            pil = img

        x1 = self.augment(pil)
        x2 = self.augment(pil)
        return x1, x2

# =========================
# Model (SimCLR wrapper)
# =========================
class SimCLR(nn.Module):
    def __init__(self, base_model, projection_dim=128):
        super().__init__()
        self.encoder = base_model  # resnet50 outputs 1000-dim
        self.projection = nn.Sequential(
            nn.Linear(1000, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, projection_dim)
        )

    def forward(self, x):
        h = self.encoder(x)    # (N, 1000)
        z = self.projection(h) # (N, projection_dim)
        return h, z

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z1 = F.normalize(z1, dim=1)
    z2 = F.normalize(z2, dim=1)
    z  = torch.cat([z1, z2], dim=0)   # (2N, D)

    sim = torch.matmul(z, z.T) / temperature         # (2N, 2N)
    mask = torch.eye(2*N, dtype=torch.bool, device=z.device)
    sim = sim.masked_fill(mask, -9e15)               # remove self-similarity

    # positives: for every i in [0..N-1], pair i with i+N and vice versa
    pos = torch.cat([torch.diag(sim, N), torch.diag(sim, -N)], dim=0)  # (2N,)
    # negatives: the rest
    neg = sim

    logits = torch.cat([pos.unsqueeze(1), neg], dim=1)  # (2N, 1 + (2N-1))
    labels = torch.zeros(2*N, dtype=torch.long, device=z.device)  # positives at index 0
    loss = F.cross_entropy(logits, labels)
    return loss

# =========================
# Data prep + split
# =========================
all_paths, all_labels, class_names = list_images_and_labels(root_dir)
num_classes = len(class_names)

train_paths, test_paths, train_labels, test_labels = train_test_split(
    all_paths, all_labels,
    test_size=test_ratio,
    stratify=all_labels,
    random_state=seed
)

# For SimCLR pretraining we need PIL images (no tensor yet)
train_dataset_pil = MalimgDatasetFromList(train_paths, train_labels, transform=None)

# Augmentations for SimCLR
simclr_augment = T.Compose([
    T.RandomResizedCrop(224),
    T.RandomHorizontalFlip(),
    T.RandomApply([T.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

contrastive_dataset = ContrastiveDataset(train_dataset_pil, simclr_augment)

# WeightedRandomSampler (train split)
class_counts = np.bincount(train_labels, minlength=num_classes).astype(np.float32)
class_counts[class_counts == 0] = 1.0
weights_per_class = 1.0 / class_counts
sample_weights = np.array([weights_per_class[y] for y in train_labels], dtype=np.float32)
train_sampler = WeightedRandomSampler(
    weights=torch.as_tensor(sample_weights),
    num_samples=len(sample_weights),
    replacement=True
)

contrastive_loader = DataLoader(
    contrastive_dataset,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=2,
    pin_memory=True
)

# Classification datasets/loaders
train_transform_cls = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor()
])
test_transform_cls = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor()
])

train_dataset_cls = MalimgDatasetFromList(train_paths, train_labels, transform=train_transform_cls)
test_dataset_cls  = MalimgDatasetFromList(test_paths,  test_labels,  transform=test_transform_cls)

# Use the same sampler for classification training loader
train_loader_cls = DataLoader(
    train_dataset_cls,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=2,
    pin_memory=True
)
test_loader = DataLoader(
    test_dataset_cls,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

# =========================
# Build models
# =========================
base_model = models.resnet50(pretrained=True)  # keep same
simclr_model = SimCLR(base_model, projection_dim=projection_dim).to(device)

optimizer = optim.Adam(simclr_model.parameters(), lr=learning_rate)

# =========================
# Pretraining (SimCLR) + timing
# =========================
pretrain_start = time.time()
best_train_loss = float("inf")
no_improve = 0

for epoch in range(pretrain_epochs):
    simclr_model.train()
    running_loss = 0.0
    for (x1, x2) in tqdm(contrastive_loader, desc=f"SimCLR Pretrain {epoch+1}/{pretrain_epochs}"):
        x1, x2 = x1.to(device, non_blocking=True), x2.to(device, non_blocking=True)

        _, z1 = simclr_model(x1)
        _, z2 = simclr_model(x2)
        loss = nt_xent_loss(z1, z2, temperature=temperature)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / max(1, len(contrastive_loader))
    print(f"[Pretrain] Epoch {epoch+1}/{pretrain_epochs} | Loss: {epoch_loss:.4f}")

    # (Optional) Early stop on SimCLR training loss as well
    if epoch_loss + 1e-6 < best_train_loss:
        best_train_loss = epoch_loss
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping SimCLR pretraining at epoch {epoch+1} (no improvement for {patience} epochs).")
            break

if device.type == "cuda":
    torch.cuda.synchronize()
pretrain_time = time.time() - pretrain_start
print(f"Pretraining time: {pretrain_time/60:.2f} min")

# =========================
# Fine-tune classifier (train split only) with early stopping + timing
# =========================
classifier = nn.Linear(1000, num_classes).to(device)
criterion  = nn.CrossEntropyLoss()
optimizer_cls = optim.Adam(
    list(simclr_model.encoder.parameters()) + list(classifier.parameters()),
    lr=finetune_lr
)

best_loss = float("inf")
no_improve = 0

ft_start = time.time()
for epoch in range(finetune_epochs):
    simclr_model.train()
    classifier.train()
    running_loss = 0.0
    correct, total = 0, 0

    for imgs, labels in tqdm(train_loader_cls, desc=f"Fine-tune {epoch+1}/{finetune_epochs}"):
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        h, _ = simclr_model(imgs)
        outputs = classifier(h)
        loss = criterion(outputs, labels)

        optimizer_cls.zero_grad()
        loss.backward()
        optimizer_cls.step()

        running_loss += loss.item()

        # Train accuracy
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total   += labels.size(0)

    epoch_loss = running_loss / max(1, len(train_loader_cls))
    train_acc  = 100.0 * correct / max(1, total)
    print(f"[Fine-tune] Epoch {epoch+1}/{finetune_epochs} | Loss: {epoch_loss:.4f} | Train Acc: {train_acc:.2f}%")

    # Early stopping on training loss (since no val set requested)
    if epoch_loss + 1e-6 < best_loss:
        best_loss = epoch_loss
        no_improve = 0
        # Save best weights
        torch.save(simclr_model.encoder.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_encoder_best.pth")
        torch.save(classifier.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_best.pth")
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping fine-tuning at epoch {epoch+1} (no improvement for {patience} epochs).")
            break

if device.type == "cuda":
    torch.cuda.synchronize()
finetune_time = time.time() - ft_start
print(f"Fine-tune time: {finetune_time/60:.2f} min")
print(f"Total training time: {(pretrain_time + finetune_time)/60:.2f} min")

# Load best weights (from fine-tune)
simclr_model.encoder.load_state_dict(torch.load("/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_encoder_best.pth"))
classifier.load_state_dict(torch.load("/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_best.pth"))
simclr_model.eval()
classifier.eval()

# =========================
# Test Evaluation (accuracy, report, confusion matrix, avg inference time)
# =========================
all_preds, all_labels = [], []
inference_images = 0
total_infer_time = 0.0

with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Testing"):
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        if device.type == "cuda":
            torch.cuda.synchronize()
        t0 = time.time()

        h, _ = simclr_model(imgs)
        outputs = classifier(h)

        if device.type == "cuda":
            torch.cuda.synchronize()
        t1 = time.time()

        total_infer_time += (t1 - t0)
        inference_images += imgs.size(0)

        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy().tolist())
        all_labels.extend(labels.cpu().numpy().tolist())

test_acc = accuracy_score(all_labels, all_preds) * 100.0
avg_infer_ms = (total_infer_time / max(1, inference_images)) * 1000.0
print(f"Test Accuracy: {test_acc:.2f}%")
print(f"Average Inference Time (per image): {avg_infer_ms:.3f} ms")

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names, digits=4))

# Confusion Matrix (matplotlib only, no seaborn)
cm = confusion_matrix(all_labels, all_preds, labels=list(range(num_classes)))

plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, class_names, rotation=90)
plt.yticks(tick_marks, class_names)
plt.tight_layout()
plt.show()

# =========================
# t-SNE on test features (from encoder output h)
# =========================
features, labels_tsne = [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Extracting features for t-SNE"):
        imgs = imgs.to(device, non_blocking=True)
        h, _ = simclr_model(imgs)        # h is (N, 1000)
        features.append(h.cpu().numpy())
        labels_tsne.extend(labels.numpy())
features = np.concatenate(features, axis=0)
labels_tsne = np.array(labels_tsne)

tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, random_state=seed, n_iter=1000)
features_2d = tsne.fit_transform(features)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], c=labels_tsne, s=10, alpha=0.7)
plt.title("t-SNE of Encoder Features (Test Set)")
plt.tight_layout()
plt.show()

# =========================
# Final save
# =========================
torch.save(simclr_model.encoder.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLRsimclr_resnet50_encoder_final.pth")
torch.save(classifier.state_dict(),          "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_final.pth")
print("Done. Saved best & final weights.")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 191MB/s]
# SimCLR Pretrain 1/100: 100%|██████████| 44/44 [07:25<00:00, 10.13s/it]
# [Pretrain] Epoch 1/100 | Loss: 4.4834
# SimCLR Pretrain 2/100: 100%|██████████| 44/44 [02:58<00:00,  4.05s/it]
# [Pretrain] Epoch 2/100 | Loss: 4.2831
# SimCLR Pretrain 3/100: 100%|██████████| 44/44 [02:00<00:00,  2.74s/it]
# [Pretrain] Epoch 3/100 | Loss: 4.2204
# SimCLR Pretrain 4/100: 100%|██████████| 44/44 [01:51<00:00,  2.53s/it]
# [Pretrain] Epoch 4/100 | Loss: 4.1841
# SimCLR Pretrain 5/100: 100%|██████████| 44/44 [01:30<00:00,  2.05s/it]
# [Pretrain] Epoch 5/100 | Loss: 4.1590
# SimCLR Pretrain 6/100: 100%|██████████| 44/44 [01:17<00:00,  1.76s/it]
# [Pretrain] Epoch 6/100 | Loss: 4.1232
# SimCLR Pretrain 7/100: 100%|██████████| 44/44 [01:14<00:00,  1.69s/it]
# [Pretrain] Epoch 7/100 | Loss: 4.1343
# SimCLR Pretrain 8/100: 100%|██████████| 44/44 [01:17<00:00,  1.76s/it]
# [Pretrain] Epoch 8/100 | Loss: 4.0898
# SimCLR Pretrain 9/100: 100%|██████████| 44/44 [01:13<00:00,  1.67s/it]
# [Pretrain] Epoch 9/100 | Loss: 4.0749
# SimCLR Pretrain 10/100: 100%|██████████| 44/44 [01:04<00:00,  1.46s/it]
# [Pretrain] Epoch 10/100 | Loss: 4.0702
# SimCLR Pretrain 11/100: 100%|██████████| 44/44 [01:10<00:00,  1.59s/it]
# [Pretrain] Epoch 11/100 | Loss: 4.0390
# SimCLR Pretrain 12/100: 100%|██████████| 44/44 [01:01<00:00,  1.39s/it]
# [Pretrain] Epoch 12/100 | Loss: 4.0512
# SimCLR Pretrain 13/100: 100%|██████████| 44/44 [01:01<00:00,  1.40s/it]
# [Pretrain] Epoch 13/100 | Loss: 4.0390
# SimCLR Pretrain 14/100: 100%|██████████| 44/44 [00:58<00:00,  1.33s/it]
# [Pretrain] Epoch 14/100 | Loss: 4.0315
# SimCLR Pretrain 15/100: 100%|██████████| 44/44 [00:57<00:00,  1.31s/it]
# [Pretrain] Epoch 15/100 | Loss: 4.0325
# SimCLR Pretrain 16/100: 100%|██████████| 44/44 [00:56<00:00,  1.29s/it]
# [Pretrain] Epoch 16/100 | Loss: 4.0042
# SimCLR Pretrain 17/100: 100%|██████████| 44/44 [00:56<00:00,  1.28s/it]
# [Pretrain] Epoch 17/100 | Loss: 3.9944
# SimCLR Pretrain 18/100: 100%|██████████| 44/44 [00:55<00:00,  1.26s/it]
# [Pretrain] Epoch 18/100 | Loss: 3.9965
# SimCLR Pretrain 19/100: 100%|██████████| 44/44 [00:54<00:00,  1.24s/it]
# [Pretrain] Epoch 19/100 | Loss: 3.9849
# SimCLR Pretrain 20/100: 100%|██████████| 44/44 [00:56<00:00,  1.28s/it]
# [Pretrain] Epoch 20/100 | Loss: 3.9889
# SimCLR Pretrain 21/100: 100%|██████████| 44/44 [00:52<00:00,  1.20s/it]
# [Pretrain] Epoch 21/100 | Loss: 3.9758
# SimCLR Pretrain 22/100: 100%|██████████| 44/44 [00:52<00:00,  1.19s/it]
# [Pretrain] Epoch 22/100 | Loss: 3.9773
# SimCLR Pretrain 23/100: 100%|██████████| 44/44 [00:51<00:00,  1.18s/it]
# [Pretrain] Epoch 23/100 | Loss: 3.9796
# SimCLR Pretrain 24/100: 100%|██████████| 44/44 [00:52<00:00,  1.20s/it]
# [Pretrain] Epoch 24/100 | Loss: 3.9876
# SimCLR Pretrain 25/100: 100%|██████████| 44/44 [00:52<00:00,  1.18s/it]
# [Pretrain] Epoch 25/100 | Loss: 3.9933
# SimCLR Pretrain 26/100: 100%|██████████| 44/44 [00:52<00:00,  1.18s/it]
# [Pretrain] Epoch 26/100 | Loss: 3.9958
# Early stopping SimCLR pretraining at epoch 26 (no improvement for 5 epochs).
# Pretraining time: 36.93 min
# Fine-tune 1/100: 100%|██████████| 44/44 [00:21<00:00,  2.01it/s]
# [Fine-tune] Epoch 1/100 | Loss: 1.3741 | Train Acc: 70.07%
# Fine-tune 2/100: 100%|██████████| 44/44 [00:25<00:00,  1.71it/s]
# [Fine-tune] Epoch 2/100 | Loss: 0.1831 | Train Acc: 91.60%
# Fine-tune 3/100: 100%|██████████| 44/44 [00:25<00:00,  1.73it/s]
# [Fine-tune] Epoch 3/100 | Loss: 0.1324 | Train Acc: 93.43%
# Fine-tune 4/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 4/100 | Loss: 0.0983 | Train Acc: 94.65%
# Fine-tune 5/100: 100%|██████████| 44/44 [00:24<00:00,  1.80it/s]
# [Fine-tune] Epoch 5/100 | Loss: 0.0853 | Train Acc: 95.40%
# Fine-tune 6/100: 100%|██████████| 44/44 [00:24<00:00,  1.79it/s]
# [Fine-tune] Epoch 6/100 | Loss: 0.0725 | Train Acc: 95.68%
# Fine-tune 7/100: 100%|██████████| 44/44 [00:24<00:00,  1.79it/s]
# [Fine-tune] Epoch 7/100 | Loss: 0.0696 | Train Acc: 96.18%
# Fine-tune 8/100: 100%|██████████| 44/44 [00:24<00:00,  1.77it/s]
# [Fine-tune] Epoch 8/100 | Loss: 0.0653 | Train Acc: 95.86%
# Fine-tune 9/100: 100%|██████████| 44/44 [00:25<00:00,  1.74it/s]
# [Fine-tune] Epoch 9/100 | Loss: 0.0579 | Train Acc: 97.13%
# Fine-tune 10/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 10/100 | Loss: 0.0311 | Train Acc: 98.82%
# Fine-tune 11/100: 100%|██████████| 44/44 [00:24<00:00,  1.79it/s]
# [Fine-tune] Epoch 11/100 | Loss: 0.0317 | Train Acc: 98.84%
# Fine-tune 12/100: 100%|██████████| 44/44 [00:21<00:00,  2.02it/s]
# [Fine-tune] Epoch 12/100 | Loss: 0.0026 | Train Acc: 99.98%
# Fine-tune 13/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 13/100 | Loss: 0.0015 | Train Acc: 100.00%
# Fine-tune 14/100: 100%|██████████| 44/44 [00:24<00:00,  1.81it/s]
# [Fine-tune] Epoch 14/100 | Loss: 0.0014 | Train Acc: 100.00%
# Fine-tune 15/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 15/100 | Loss: 0.0011 | Train Acc: 100.00%
# Fine-tune 16/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 16/100 | Loss: 0.0009 | Train Acc: 100.00%
# Fine-tune 17/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 17/100 | Loss: 0.0008 | Train Acc: 100.00%
# Fine-tune 18/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 18/100 | Loss: 0.0012 | Train Acc: 99.96%
# Fine-tune 19/100: 100%|██████████| 44/44 [00:21<00:00,  2.05it/s]
# [Fine-tune] Epoch 19/100 | Loss: 0.0012 | Train Acc: 99.98%
# Fine-tune 20/100: 100%|██████████| 44/44 [00:21<00:00,  2.01it/s]
# [Fine-tune] Epoch 20/100 | Loss: 0.0012 | Train Acc: 99.98%
# Fine-tune 21/100: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s]
# [Fine-tune] Epoch 21/100 | Loss: 0.0007 | Train Acc: 100.00%
# Fine-tune 22/100: 100%|██████████| 44/44 [00:23<00:00,  1.84it/s]
# [Fine-tune] Epoch 22/100 | Loss: 0.0006 | Train Acc: 100.00%
# Fine-tune 23/100: 100%|██████████| 44/44 [00:23<00:00,  1.84it/s]
# [Fine-tune] Epoch 23/100 | Loss: 0.0006 | Train Acc: 99.98%
# Fine-tune 24/100: 100%|██████████| 44/44 [00:23<00:00,  1.85it/s]
# [Fine-tune] Epoch 24/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 25/100: 100%|██████████| 44/44 [00:23<00:00,  1.85it/s]
# [Fine-tune] Epoch 25/100 | Loss: 0.0003 | Train Acc: 100.00%
# Fine-tune 26/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 26/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 27/100: 100%|██████████| 44/44 [00:21<00:00,  2.05it/s]
# [Fine-tune] Epoch 27/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 28/100: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s]
# [Fine-tune] Epoch 28/100 | Loss: 0.0003 | Train Acc: 100.00%
# Fine-tune 29/100: 100%|██████████| 44/44 [00:23<00:00,  1.84it/s]
# [Fine-tune] Epoch 29/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 30/100: 100%|██████████| 44/44 [00:21<00:00,  2.02it/s]
# [Fine-tune] Epoch 30/100 | Loss: 0.0003 | Train Acc: 100.00%
# Fine-tune 31/100: 100%|██████████| 44/44 [00:22<00:00,  1.99it/s]
# [Fine-tune] Epoch 31/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 32/100: 100%|██████████| 44/44 [00:23<00:00,  1.85it/s]
# [Fine-tune] Epoch 32/100 | Loss: 0.0003 | Train Acc: 100.00%
# Fine-tune 33/100: 100%|██████████| 44/44 [00:21<00:00,  2.00it/s]
# [Fine-tune] Epoch 33/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 34/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 34/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 35/100: 100%|██████████| 44/44 [00:23<00:00,  1.83it/s]
# [Fine-tune] Epoch 35/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 36/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 36/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 37/100: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s]
# [Fine-tune] Epoch 37/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 38/100: 100%|██████████| 44/44 [00:23<00:00,  1.85it/s]
# [Fine-tune] Epoch 38/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 39/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 39/100 | Loss: 0.0002 | Train Acc: 100.00%
# Fine-tune 40/100: 100%|██████████| 44/44 [00:21<00:00,  2.03it/s]
# [Fine-tune] Epoch 40/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 41/100: 100%|██████████| 44/44 [00:24<00:00,  1.82it/s]
# [Fine-tune] Epoch 41/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 42/100: 100%|██████████| 44/44 [00:21<00:00,  2.06it/s]
# [Fine-tune] Epoch 42/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 43/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 43/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 44/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 44/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 45/100: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s]
# [Fine-tune] Epoch 45/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 46/100: 100%|██████████| 44/44 [00:21<00:00,  2.02it/s]
# [Fine-tune] Epoch 46/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 47/100: 100%|██████████| 44/44 [00:21<00:00,  2.02it/s]
# [Fine-tune] Epoch 47/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 48/100: 100%|██████████| 44/44 [00:21<00:00,  2.06it/s]
# [Fine-tune] Epoch 48/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 49/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 49/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 50/100: 100%|██████████| 44/44 [00:21<00:00,  2.03it/s]
# [Fine-tune] Epoch 50/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 51/100: 100%|██████████| 44/44 [00:24<00:00,  1.83it/s]
# [Fine-tune] Epoch 51/100 | Loss: 0.0001 | Train Acc: 100.00%
# Fine-tune 52/100: 100%|██████████| 44/44 [00:23<00:00,  1.85it/s]
# [Fine-tune] Epoch 52/100 | Loss: 0.0022 | Train Acc: 99.96%
# Fine-tune 53/100: 100%|██████████| 44/44 [00:21<00:00,  2.04it/s]
# [Fine-tune] Epoch 53/100 | Loss: 0.0246 | Train Acc: 99.29%
# Fine-tune 54/100: 100%|██████████| 44/44 [00:22<00:00,  2.00it/s]
# [Fine-tune] Epoch 54/100 | Loss: 0.0334 | Train Acc: 99.13%
# Fine-tune 55/100: 100%|██████████| 44/44 [00:21<00:00,  2.05it/s]
# [Fine-tune] Epoch 55/100 | Loss: 0.0237 | Train Acc: 99.39%
# Fine-tune 56/100: 100%|██████████| 44/44 [00:22<00:00,  1.98it/s]
# [Fine-tune] Epoch 56/100 | Loss: 0.0064 | Train Acc: 99.77%
# Early stopping fine-tuning at epoch 56 (no improvement for 5 epochs).
# Fine-tune time: 22.07 min
# Total training time: 59.00 min
# Testing: 100%|██████████| 30/30 [10:25<00:00, 20.85s/it]
# Test Accuracy: 99.12%
# Average Inference Time (per image): 0.381 ms
# Classification Report:
#                 precision    recall  f1-score   support
#
#      Adialer.C     1.0000    1.0000    1.0000        49
#      Agent.FYI     1.0000    1.0000    1.0000        47
#      Allaple.A     0.9992    1.0000    0.9996      1180
#      Allaple.L     1.0000    1.0000    1.0000       636
#  Alueron.gen!J     1.0000    1.0000    1.0000        79
#      Autorun.K     1.0000    1.0000    1.0000        42
#        C2LOP.P     0.9091    0.8621    0.8850        58
#    C2LOP.gen!g     0.9302    1.0000    0.9639        80
# Dialplatform.B     1.0000    1.0000    1.0000        71
#      Dontovo.A     1.0000    1.0000    1.0000        65
#       Fakerean     1.0000    0.9935    0.9967       153
#  Instantaccess     1.0000    1.0000    1.0000       172
#     Lolyda.AA1     0.9770    1.0000    0.9884        85
#     Lolyda.AA2     0.9863    0.9730    0.9796        74
#     Lolyda.AA3     1.0000    1.0000    1.0000        49
#      Lolyda.AT     1.0000    1.0000    1.0000        64
#    Malex.gen!J     1.0000    0.9630    0.9811        54
#  Obfuscator.AD     1.0000    1.0000    1.0000        57
#       Rbot!gen     1.0000    0.9841    0.9920        63
#     Skintrim.N     1.0000    1.0000    1.0000        32
#  Swizzor.gen!E     0.8627    0.8627    0.8627        51
#  Swizzor.gen!I     0.8269    0.8113    0.8190        53
#          VB.AT     1.0000    0.9877    0.9938       163
#     Wintrim.BX     0.9512    1.0000    0.9750        39
#        Yuner.A     1.0000    1.0000    1.0000       320
#
#       accuracy                         0.9912      3736
#      macro avg     0.9777    0.9775    0.9775      3736
#   weighted avg     0.9912    0.9912    0.9911      3736
# Extracting features for t-SNE: 100%|██████████| 30/30 [00:12<00:00,  2.32it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Done. Saved best & final weights.
