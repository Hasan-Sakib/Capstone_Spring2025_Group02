# %%
# =========================
# Imports
# =========================
import os, time, random
import numpy as np
from glob import glob

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.models as models
import torchvision.transforms as T

from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler

from PIL import Image
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Reproducibility
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# =========================
# Paths & Hyperparams
# =========================
# Set this to your Malimg root where subfolders are class names:
root_dir = "/content/drive/MyDrive/Colab Notebooks/malimg_paper_dataset_imgs"

batch_size = 128
pretrain_epochs = 100
finetune_epochs = 100     # early stopping can cut this short
learning_rate = 1e-3     # for SimCLR
finetune_lr  = 1e-4      # for classifier + encoder
temperature  = 0.5
projection_dim = 128
test_ratio = 0.8
patience = 5             # early stopping on train loss (no val per your request)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================
# Dataset helpers
# =========================
def list_images_and_labels(root_dir):
    class_names = sorted([d for d in os.listdir(root_dir)
                          if os.path.isdir(os.path.join(root_dir, d))])
    class_to_idx = {c:i for i,c in enumerate(class_names)}
    img_paths, labels = [], []
    for cls in class_names:
        cls_path = os.path.join(root_dir, cls)
        for f in os.listdir(cls_path):
            p = os.path.join(cls_path, f)
            if os.path.isfile(p):
                img_paths.append(p)
                labels.append(class_to_idx[cls])
    return img_paths, labels, class_names

class MalimgDatasetFromList(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img = Image.open(self.image_paths[idx]).convert("RGB")
        label = self.labels[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

class ContrastiveDataset(Dataset):
    """ Wrap a base dataset & return two augmented views for SimCLR. """
    def __init__(self, base_dataset, augment):
        self.base = base_dataset
        self.augment = augment

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, _ = self.base[idx]     # base returns (PIL-transformed tensor, label)
        # If base returns tensors already, ensure augment expects PIL -> ToTensor inside
        # Here, we want PIL input; so build base without transform, and put transforms here.
        # To make that work, ensure base has transform=None (we will below).
        # We'll handle it by reloading image path via base.image_paths if needed.
        # Simpler: create a PIL loader dataset for contrastive step:
        # We'll reconstruct PIL image by path to guarantee augment works.

        # Re-open PIL to ensure augment gets PIL (in case base had ToTensor)
        # (This requires base to have .image_paths; we can check and fallback.)
        if hasattr(self.base, "image_paths"):
            pil = Image.open(self.base.image_paths[idx]).convert("RGB")
        else:
            # Fallback: assume img is PIL already
            pil = img

        x1 = self.augment(pil)
        x2 = self.augment(pil)
        return x1, x2

# =========================
# Model (SimCLR wrapper)
# =========================
class SimCLR(nn.Module):
    def __init__(self, base_model, projection_dim=128):
        super().__init__()
        self.encoder = base_model  # resnet50 outputs 1000-dim
        self.projection = nn.Sequential(
            nn.Linear(1000, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, projection_dim)
        )

    def forward(self, x):
        h = self.encoder(x)    # (N, 1000)
        z = self.projection(h) # (N, projection_dim)
        return h, z

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z1 = F.normalize(z1, dim=1)
    z2 = F.normalize(z2, dim=1)
    z  = torch.cat([z1, z2], dim=0)   # (2N, D)

    sim = torch.matmul(z, z.T) / temperature         # (2N, 2N)
    mask = torch.eye(2*N, dtype=torch.bool, device=z.device)
    sim = sim.masked_fill(mask, -9e15)               # remove self-similarity

    # positives: for every i in [0..N-1], pair i with i+N and vice versa
    pos = torch.cat([torch.diag(sim, N), torch.diag(sim, -N)], dim=0)  # (2N,)
    # negatives: the rest
    neg = sim

    logits = torch.cat([pos.unsqueeze(1), neg], dim=1)  # (2N, 1 + (2N-1))
    labels = torch.zeros(2*N, dtype=torch.long, device=z.device)  # positives at index 0
    loss = F.cross_entropy(logits, labels)
    return loss

# =========================
# Data prep + split
# =========================
all_paths, all_labels, class_names = list_images_and_labels(root_dir)
num_classes = len(class_names)

train_paths, test_paths, train_labels, test_labels = train_test_split(
    all_paths, all_labels,
    test_size=test_ratio,
    stratify=all_labels,
    random_state=seed
)

# For SimCLR pretraining we need PIL images (no tensor yet)
train_dataset_pil = MalimgDatasetFromList(train_paths, train_labels, transform=None)

# Augmentations for SimCLR
simclr_augment = T.Compose([
    T.RandomResizedCrop(224),
    T.RandomHorizontalFlip(),
    T.RandomApply([T.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

contrastive_dataset = ContrastiveDataset(train_dataset_pil, simclr_augment)

# WeightedRandomSampler (train split)
class_counts = np.bincount(train_labels, minlength=num_classes).astype(np.float32)
class_counts[class_counts == 0] = 1.0
weights_per_class = 1.0 / class_counts
sample_weights = np.array([weights_per_class[y] for y in train_labels], dtype=np.float32)
train_sampler = WeightedRandomSampler(
    weights=torch.as_tensor(sample_weights),
    num_samples=len(sample_weights),
    replacement=True
)

contrastive_loader = DataLoader(
    contrastive_dataset,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=2,
    pin_memory=True
)

# Classification datasets/loaders
train_transform_cls = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor()
])
test_transform_cls = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor()
])

train_dataset_cls = MalimgDatasetFromList(train_paths, train_labels, transform=train_transform_cls)
test_dataset_cls  = MalimgDatasetFromList(test_paths,  test_labels,  transform=test_transform_cls)

# Use the same sampler for classification training loader
train_loader_cls = DataLoader(
    train_dataset_cls,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=2,
    pin_memory=True
)
test_loader = DataLoader(
    test_dataset_cls,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

# =========================
# Build models
# =========================
base_model = models.resnet50(pretrained=True)  # keep same
simclr_model = SimCLR(base_model, projection_dim=projection_dim).to(device)

optimizer = optim.Adam(simclr_model.parameters(), lr=learning_rate)

# =========================
# Pretraining (SimCLR) + timing
# =========================
pretrain_start = time.time()
best_train_loss = float("inf")
no_improve = 0

for epoch in range(pretrain_epochs):
    simclr_model.train()
    running_loss = 0.0
    for (x1, x2) in tqdm(contrastive_loader, desc=f"SimCLR Pretrain {epoch+1}/{pretrain_epochs}"):
        x1, x2 = x1.to(device, non_blocking=True), x2.to(device, non_blocking=True)

        _, z1 = simclr_model(x1)
        _, z2 = simclr_model(x2)
        loss = nt_xent_loss(z1, z2, temperature=temperature)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / max(1, len(contrastive_loader))
    print(f"[Pretrain] Epoch {epoch+1}/{pretrain_epochs} | Loss: {epoch_loss:.4f}")

    # (Optional) Early stop on SimCLR training loss as well
    if epoch_loss + 1e-6 < best_train_loss:
        best_train_loss = epoch_loss
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping SimCLR pretraining at epoch {epoch+1} (no improvement for {patience} epochs).")
            break

if device.type == "cuda":
    torch.cuda.synchronize()
pretrain_time = time.time() - pretrain_start
print(f"Pretraining time: {pretrain_time/60:.2f} min")

# =========================
# Fine-tune classifier (train split only) with early stopping + timing
# =========================
classifier = nn.Linear(1000, num_classes).to(device)
criterion  = nn.CrossEntropyLoss()
optimizer_cls = optim.Adam(
    list(simclr_model.encoder.parameters()) + list(classifier.parameters()),
    lr=finetune_lr
)

best_loss = float("inf")
no_improve = 0

ft_start = time.time()
for epoch in range(finetune_epochs):
    simclr_model.train()
    classifier.train()
    running_loss = 0.0
    correct, total = 0, 0

    for imgs, labels in tqdm(train_loader_cls, desc=f"Fine-tune {epoch+1}/{finetune_epochs}"):
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        h, _ = simclr_model(imgs)
        outputs = classifier(h)
        loss = criterion(outputs, labels)

        optimizer_cls.zero_grad()
        loss.backward()
        optimizer_cls.step()

        running_loss += loss.item()

        # Train accuracy
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total   += labels.size(0)

    epoch_loss = running_loss / max(1, len(train_loader_cls))
    train_acc  = 100.0 * correct / max(1, total)
    print(f"[Fine-tune] Epoch {epoch+1}/{finetune_epochs} | Loss: {epoch_loss:.4f} | Train Acc: {train_acc:.2f}%")

    # Early stopping on training loss (since no val set requested)
    if epoch_loss + 1e-6 < best_loss:
        best_loss = epoch_loss
        no_improve = 0
        # Save best weights
        torch.save(simclr_model.encoder.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_encoder_best.pth")
        torch.save(classifier.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_best.pth")
    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping fine-tuning at epoch {epoch+1} (no improvement for {patience} epochs).")
            break

if device.type == "cuda":
    torch.cuda.synchronize()
finetune_time = time.time() - ft_start
print(f"Fine-tune time: {finetune_time/60:.2f} min")
print(f"Total training time: {(pretrain_time + finetune_time)/60:.2f} min")

# Load best weights (from fine-tune)
simclr_model.encoder.load_state_dict(torch.load("/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_encoder_best.pth"))
classifier.load_state_dict(torch.load("/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_best.pth"))
simclr_model.eval()
classifier.eval()

# =========================
# Test Evaluation (accuracy, report, confusion matrix, avg inference time)
# =========================
all_preds, all_labels = [], []
inference_images = 0
total_infer_time = 0.0

with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Testing"):
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        if device.type == "cuda":
            torch.cuda.synchronize()
        t0 = time.time()

        h, _ = simclr_model(imgs)
        outputs = classifier(h)

        if device.type == "cuda":
            torch.cuda.synchronize()
        t1 = time.time()

        total_infer_time += (t1 - t0)
        inference_images += imgs.size(0)

        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy().tolist())
        all_labels.extend(labels.cpu().numpy().tolist())

test_acc = accuracy_score(all_labels, all_preds) * 100.0
avg_infer_ms = (total_infer_time / max(1, inference_images)) * 1000.0
print(f"Test Accuracy: {test_acc:.2f}%")
print(f"Average Inference Time (per image): {avg_infer_ms:.3f} ms")

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names, digits=4))

# Confusion Matrix (matplotlib only, no seaborn)
cm = confusion_matrix(all_labels, all_preds, labels=list(range(num_classes)))

plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, class_names, rotation=90)
plt.yticks(tick_marks, class_names)
plt.tight_layout()
plt.show()

# =========================
# t-SNE on test features (from encoder output h)
# =========================
features, labels_tsne = [], []
with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Extracting features for t-SNE"):
        imgs = imgs.to(device, non_blocking=True)
        h, _ = simclr_model(imgs)        # h is (N, 1000)
        features.append(h.cpu().numpy())
        labels_tsne.extend(labels.numpy())
features = np.concatenate(features, axis=0)
labels_tsne = np.array(labels_tsne)

tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, random_state=seed, n_iter=1000)
features_2d = tsne.fit_transform(features)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], c=labels_tsne, s=10, alpha=0.7)
plt.title("t-SNE of Encoder Features (Test Set)")
plt.tight_layout()
plt.show()

# =========================
# Final save
# =========================
torch.save(simclr_model.encoder.state_dict(), "/content/drive/MyDrive/Colab Notebooks/SimCLRsimclr_resnet50_encoder_final.pth")
torch.save(classifier.state_dict(),          "/content/drive/MyDrive/Colab Notebooks/SimCLR/simclr_resnet50_classifier_final.pth")
print("Done. Saved best & final weights.")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# SimCLR Pretrain 1/100: 100%|██████████| 15/15 [00:18<00:00,  1.20s/it]
# [Pretrain] Epoch 1/100 | Loss: 4.7590
# SimCLR Pretrain 2/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 2/100 | Loss: 4.4320
# SimCLR Pretrain 3/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 3/100 | Loss: 4.3367
# SimCLR Pretrain 4/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 4/100 | Loss: 4.3054
# SimCLR Pretrain 5/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 5/100 | Loss: 4.3009
# SimCLR Pretrain 6/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 6/100 | Loss: 4.2477
# SimCLR Pretrain 7/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 7/100 | Loss: 4.2248
# SimCLR Pretrain 8/100: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
# [Pretrain] Epoch 8/100 | Loss: 4.2460
# SimCLR Pretrain 9/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 9/100 | Loss: 4.2419
# SimCLR Pretrain 10/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 10/100 | Loss: 4.1834
# SimCLR Pretrain 11/100: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
# [Pretrain] Epoch 11/100 | Loss: 4.1570
# SimCLR Pretrain 12/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 12/100 | Loss: 4.1912
# SimCLR Pretrain 13/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 13/100 | Loss: 4.1387
# SimCLR Pretrain 14/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 14/100 | Loss: 4.1519
# SimCLR Pretrain 15/100: 100%|██████████| 15/15 [00:17<00:00,  1.20s/it]
# [Pretrain] Epoch 15/100 | Loss: 4.1618
# SimCLR Pretrain 16/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 16/100 | Loss: 4.1503
# SimCLR Pretrain 17/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 17/100 | Loss: 4.1338
# SimCLR Pretrain 18/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 18/100 | Loss: 4.1209
# SimCLR Pretrain 19/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 19/100 | Loss: 4.0863
# SimCLR Pretrain 20/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 20/100 | Loss: 4.0982
# SimCLR Pretrain 21/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 21/100 | Loss: 4.0798
# SimCLR Pretrain 22/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 22/100 | Loss: 4.0799
# SimCLR Pretrain 23/100: 100%|██████████| 15/15 [00:18<00:00,  1.20s/it]
# [Pretrain] Epoch 23/100 | Loss: 4.0556
# SimCLR Pretrain 24/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 24/100 | Loss: 4.0561
# SimCLR Pretrain 25/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 25/100 | Loss: 4.0380
# SimCLR Pretrain 26/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 26/100 | Loss: 4.0419
# SimCLR Pretrain 27/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 27/100 | Loss: 4.0401
# SimCLR Pretrain 28/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 28/100 | Loss: 4.0291
# SimCLR Pretrain 29/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 29/100 | Loss: 4.0113
# SimCLR Pretrain 30/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 30/100 | Loss: 4.0220
# SimCLR Pretrain 31/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 31/100 | Loss: 4.0344
# SimCLR Pretrain 32/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 32/100 | Loss: 4.0163
# SimCLR Pretrain 33/100: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
# [Pretrain] Epoch 33/100 | Loss: 4.0055
# SimCLR Pretrain 34/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 34/100 | Loss: 4.0525
# SimCLR Pretrain 35/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 35/100 | Loss: 4.0234
# SimCLR Pretrain 36/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 36/100 | Loss: 4.0006
# SimCLR Pretrain 37/100: 100%|██████████| 15/15 [00:17<00:00,  1.16s/it]
# [Pretrain] Epoch 37/100 | Loss: 4.0215
# SimCLR Pretrain 38/100: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
# [Pretrain] Epoch 38/100 | Loss: 4.0138
# SimCLR Pretrain 39/100: 100%|██████████| 15/15 [00:17<00:00,  1.19s/it]
# [Pretrain] Epoch 39/100 | Loss: 3.9993
# SimCLR Pretrain 40/100: 100%|██████████| 15/15 [00:17<00:00,  1.15s/it]
# [Pretrain] Epoch 40/100 | Loss: 3.9978
# SimCLR Pretrain 41/100: 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]
# [Pretrain] Epoch 41/100 | Loss: 3.9857
# SimCLR Pretrain 42/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 42/100 | Loss: 4.0167
# SimCLR Pretrain 43/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 43/100 | Loss: 4.0198
# SimCLR Pretrain 44/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 44/100 | Loss: 4.0120
# SimCLR Pretrain 45/100: 100%|██████████| 15/15 [00:17<00:00,  1.17s/it]
# [Pretrain] Epoch 45/100 | Loss: 4.0089
# SimCLR Pretrain 46/100: 100%|██████████| 15/15 [00:17<00:00,  1.18s/it]
# [Pretrain] Epoch 46/100 | Loss: 4.0012
# Early stopping SimCLR pretraining at epoch 46 (no improvement for 5 epochs).
# Pretraining time: 13.49 min
# Fine-tune 1/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 1/100 | Loss: 2.6712 | Train Acc: 37.96%
# Fine-tune 2/100: 100%|██████████| 15/15 [00:07<00:00,  1.88it/s]
# [Fine-tune] Epoch 2/100 | Loss: 0.6143 | Train Acc: 84.58%
# Fine-tune 3/100: 100%|██████████| 15/15 [00:09<00:00,  1.55it/s]
# [Fine-tune] Epoch 3/100 | Loss: 0.2920 | Train Acc: 90.04%
# Fine-tune 4/100: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# [Fine-tune] Epoch 4/100 | Loss: 0.1823 | Train Acc: 92.77%
# Fine-tune 5/100: 100%|██████████| 15/15 [00:10<00:00,  1.49it/s]
# [Fine-tune] Epoch 5/100 | Loss: 0.1578 | Train Acc: 92.02%
# Fine-tune 6/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 6/100 | Loss: 0.1172 | Train Acc: 94.27%
# Fine-tune 7/100: 100%|██████████| 15/15 [00:09<00:00,  1.57it/s]
# [Fine-tune] Epoch 7/100 | Loss: 0.1025 | Train Acc: 95.24%
# Fine-tune 8/100: 100%|██████████| 15/15 [00:08<00:00,  1.87it/s]
# [Fine-tune] Epoch 8/100 | Loss: 0.0796 | Train Acc: 96.04%
# Fine-tune 9/100: 100%|██████████| 15/15 [00:07<00:00,  1.88it/s]
# [Fine-tune] Epoch 9/100 | Loss: 0.0789 | Train Acc: 95.99%
# Fine-tune 10/100: 100%|██████████| 15/15 [00:07<00:00,  1.89it/s]
# [Fine-tune] Epoch 10/100 | Loss: 0.0809 | Train Acc: 95.29%
# Fine-tune 11/100: 100%|██████████| 15/15 [00:09<00:00,  1.57it/s]
# [Fine-tune] Epoch 11/100 | Loss: 0.0729 | Train Acc: 96.63%
# Fine-tune 12/100: 100%|██████████| 15/15 [00:07<00:00,  1.89it/s]
# [Fine-tune] Epoch 12/100 | Loss: 0.0853 | Train Acc: 95.40%
# Fine-tune 13/100: 100%|██████████| 15/15 [00:07<00:00,  1.90it/s]
# [Fine-tune] Epoch 13/100 | Loss: 0.0752 | Train Acc: 95.88%
# Fine-tune 14/100: 100%|██████████| 15/15 [00:09<00:00,  1.56it/s]
# [Fine-tune] Epoch 14/100 | Loss: 0.0724 | Train Acc: 95.88%
# Fine-tune 15/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 15/100 | Loss: 0.0711 | Train Acc: 95.72%
# Fine-tune 16/100: 100%|██████████| 15/15 [00:07<00:00,  1.95it/s]
# [Fine-tune] Epoch 16/100 | Loss: 0.0609 | Train Acc: 95.93%
# Fine-tune 17/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 17/100 | Loss: 0.0636 | Train Acc: 95.82%
# Fine-tune 18/100: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# [Fine-tune] Epoch 18/100 | Loss: 0.0594 | Train Acc: 96.36%
# Fine-tune 19/100: 100%|██████████| 15/15 [00:07<00:00,  1.92it/s]
# [Fine-tune] Epoch 19/100 | Loss: 0.0611 | Train Acc: 95.56%
# Fine-tune 20/100: 100%|██████████| 15/15 [00:09<00:00,  1.56it/s]
# [Fine-tune] Epoch 20/100 | Loss: 0.0634 | Train Acc: 96.41%
# Fine-tune 21/100: 100%|██████████| 15/15 [00:07<00:00,  1.98it/s]
# [Fine-tune] Epoch 21/100 | Loss: 0.0575 | Train Acc: 97.00%
# Fine-tune 22/100: 100%|██████████| 15/15 [00:07<00:00,  1.91it/s]
# [Fine-tune] Epoch 22/100 | Loss: 0.0458 | Train Acc: 98.61%
# Fine-tune 23/100: 100%|██████████| 15/15 [00:09<00:00,  1.52it/s]
# [Fine-tune] Epoch 23/100 | Loss: 0.0267 | Train Acc: 99.57%
# Fine-tune 24/100: 100%|██████████| 15/15 [00:10<00:00,  1.50it/s]
# [Fine-tune] Epoch 24/100 | Loss: 0.0616 | Train Acc: 97.11%
# Fine-tune 25/100: 100%|██████████| 15/15 [00:08<00:00,  1.81it/s]
# [Fine-tune] Epoch 25/100 | Loss: 0.0101 | Train Acc: 100.00%
# Fine-tune 26/100: 100%|██████████| 15/15 [00:08<00:00,  1.84it/s]
# [Fine-tune] Epoch 26/100 | Loss: 0.0036 | Train Acc: 100.00%
# Fine-tune 27/100: 100%|██████████| 15/15 [00:09<00:00,  1.51it/s]
# [Fine-tune] Epoch 27/100 | Loss: 0.0030 | Train Acc: 100.00%
# Fine-tune 28/100: 100%|██████████| 15/15 [00:09<00:00,  1.54it/s]
# [Fine-tune] Epoch 28/100 | Loss: 0.0027 | Train Acc: 100.00%
# Fine-tune 29/100: 100%|██████████| 15/15 [00:07<00:00,  1.93it/s]
# [Fine-tune] Epoch 29/100 | Loss: 0.0014 | Train Acc: 100.00%
# Fine-tune 30/100: 100%|██████████| 15/15 [00:09<00:00,  1.56it/s]
# [Fine-tune] Epoch 30/100 | Loss: 0.0015 | Train Acc: 100.00%
# Fine-tune 31/100: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# [Fine-tune] Epoch 31/100 | Loss: 0.0016 | Train Acc: 100.00%
# Fine-tune 32/100: 100%|██████████| 15/15 [00:07<00:00,  1.95it/s]
# [Fine-tune] Epoch 32/100 | Loss: 0.0013 | Train Acc: 100.00%
# Fine-tune 33/100: 100%|██████████| 15/15 [00:09<00:00,  1.55it/s]
# [Fine-tune] Epoch 33/100 | Loss: 0.0011 | Train Acc: 100.00%
# Fine-tune 34/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 34/100 | Loss: 0.0012 | Train Acc: 100.00%
# Fine-tune 35/100: 100%|██████████| 15/15 [00:07<00:00,  1.96it/s]
# [Fine-tune] Epoch 35/100 | Loss: 0.0020 | Train Acc: 100.00%
# Fine-tune 36/100: 100%|██████████| 15/15 [00:09<00:00,  1.58it/s]
# [Fine-tune] Epoch 36/100 | Loss: 0.0015 | Train Acc: 100.00%
# Fine-tune 37/100: 100%|██████████| 15/15 [00:07<00:00,  1.97it/s]
# [Fine-tune] Epoch 37/100 | Loss: 0.0015 | Train Acc: 100.00%
# Fine-tune 38/100: 100%|██████████| 15/15 [00:07<00:00,  1.95it/s]
# [Fine-tune] Epoch 38/100 | Loss: 0.0010 | Train Acc: 100.00%
# Fine-tune 39/100: 100%|██████████| 15/15 [00:07<00:00,  2.03it/s]
# [Fine-tune] Epoch 39/100 | Loss: 0.0008 | Train Acc: 100.00%
# Fine-tune 40/100: 100%|██████████| 15/15 [00:10<00:00,  1.49it/s]
# [Fine-tune] Epoch 40/100 | Loss: 0.0008 | Train Acc: 100.00%
# Fine-tune 41/100: 100%|██████████| 15/15 [00:07<00:00,  1.95it/s]
# [Fine-tune] Epoch 41/100 | Loss: 0.0009 | Train Acc: 100.00%
# Fine-tune 42/100: 100%|██████████| 15/15 [00:09<00:00,  1.57it/s]
# [Fine-tune] Epoch 42/100 | Loss: 0.0008 | Train Acc: 100.00%
# Fine-tune 43/100: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# [Fine-tune] Epoch 43/100 | Loss: 0.0006 | Train Acc: 100.00%
# Fine-tune 44/100: 100%|██████████| 15/15 [00:07<00:00,  1.89it/s]
# [Fine-tune] Epoch 44/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 45/100: 100%|██████████| 15/15 [00:09<00:00,  1.53it/s]
# [Fine-tune] Epoch 45/100 | Loss: 0.0006 | Train Acc: 100.00%
# Fine-tune 46/100: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# [Fine-tune] Epoch 46/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 47/100: 100%|██████████| 15/15 [00:07<00:00,  1.91it/s]
# [Fine-tune] Epoch 47/100 | Loss: 0.0006 | Train Acc: 100.00%
# Fine-tune 48/100: 100%|██████████| 15/15 [00:09<00:00,  1.59it/s]
# [Fine-tune] Epoch 48/100 | Loss: 0.0006 | Train Acc: 100.00%
# Fine-tune 49/100: 100%|██████████| 15/15 [00:07<00:00,  2.03it/s]
# [Fine-tune] Epoch 49/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 50/100: 100%|██████████| 15/15 [00:07<00:00,  1.90it/s]
# [Fine-tune] Epoch 50/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 51/100: 100%|██████████| 15/15 [00:07<00:00,  1.90it/s]
# [Fine-tune] Epoch 51/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 52/100: 100%|██████████| 15/15 [00:07<00:00,  1.94it/s]
# [Fine-tune] Epoch 52/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 53/100: 100%|██████████| 15/15 [00:07<00:00,  1.93it/s]
# [Fine-tune] Epoch 53/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 54/100: 100%|██████████| 15/15 [00:07<00:00,  1.99it/s]
# [Fine-tune] Epoch 54/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 55/100: 100%|██████████| 15/15 [00:09<00:00,  1.56it/s]
# [Fine-tune] Epoch 55/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 56/100: 100%|██████████| 15/15 [00:07<00:00,  1.91it/s]
# [Fine-tune] Epoch 56/100 | Loss: 0.0005 | Train Acc: 100.00%
# Fine-tune 57/100: 100%|██████████| 15/15 [00:08<00:00,  1.79it/s]
# [Fine-tune] Epoch 57/100 | Loss: 0.0004 | Train Acc: 100.00%
# Fine-tune 58/100: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# [Fine-tune] Epoch 58/100 | Loss: 0.0008 | Train Acc: 100.00%
# Early stopping fine-tuning at epoch 58 (no improvement for 5 epochs).
# Fine-tune time: 8.30 min
# Total training time: 21.79 min
# Testing: 100%|██████████| 59/59 [00:26<00:00,  2.26it/s]
# Test Accuracy: 98.69%
# Average Inference Time (per image): 0.347 ms
# Classification Report:
#                 precision    recall  f1-score   support
#
#      Adialer.C     1.0000    1.0000    1.0000        98
#      Agent.FYI     1.0000    0.9785    0.9891        93
#      Allaple.A     1.0000    1.0000    1.0000      2359
#      Allaple.L     1.0000    1.0000    1.0000      1273
#  Alueron.gen!J     1.0000    1.0000    1.0000       158
#      Autorun.K     0.9884    1.0000    0.9942        85
#        C2LOP.P     0.8769    0.9744    0.9231       117
#    C2LOP.gen!g     0.9868    0.9313    0.9582       160
# Dialplatform.B     1.0000    0.9859    0.9929       142
#      Dontovo.A     1.0000    1.0000    1.0000       130
#       Fakerean     0.9934    0.9902    0.9918       305
#  Instantaccess     1.0000    1.0000    1.0000       345
#     Lolyda.AA1     0.9605    1.0000    0.9798       170
#     Lolyda.AA2     0.9930    0.9660    0.9793       147
#     Lolyda.AA3     0.9899    1.0000    0.9949        98
#      Lolyda.AT     0.9844    0.9921    0.9882       127
#    Malex.gen!J     1.0000    0.9817    0.9907       109
#  Obfuscator.AD     1.0000    1.0000    1.0000       114
#       Rbot!gen     1.0000    0.9841    0.9920       126
#     Skintrim.N     1.0000    1.0000    1.0000        64
#  Swizzor.gen!E     0.6870    0.7745    0.7281       102
#  Swizzor.gen!I     0.7273    0.6038    0.6598       106
#          VB.AT     0.9908    0.9939    0.9923       326
#     Wintrim.BX     0.9750    1.0000    0.9873        78
#        Yuner.A     0.9984    1.0000    0.9992       640
#
#       accuracy                         0.9869      7472
#      macro avg     0.9661    0.9662    0.9656      7472
#   weighted avg     0.9870    0.9869    0.9868      7472
# Extracting features for t-SNE: 100%|██████████| 59/59 [00:25<00:00,  2.28it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Done. Saved best & final weights.
